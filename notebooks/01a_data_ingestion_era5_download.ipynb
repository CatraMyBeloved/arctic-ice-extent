# %%
import cdsapi
from pathlib import Path

# %% [markdown]
# # ERA5 Data Download
#
# This notebook downloads daily atmospheric data from the Copernicus Climate Data Store (CDS) for Arctic sea ice forecasting.

# %% [markdown]
# ## Configuration
#
# Define the ERA5 variables, time range, and spatial extent for download. The Arctic region is bounded by 55°N-90°N latitude.

# %%
dataset = "derived-era5-single-levels-daily-statistics"
variables = [
    "10m_u_component_of_wind",
    "10m_v_component_of_wind",
    "2m_temperature",
    "mean_sea_level_pressure",
    "total_precipitation",
]
days = [day for day in range(1, 32)]
years = range(1979, 2024)
months = range(1, 13)

base_request = {
    "product_type": "reanalysis",
    "variable": variables,
    "day": days,
    "daily_statistic": "daily_mean",
    "time_zone": "utc+00:00",
    "frequency": "6_hourly",
    "area": [90, -180, 55, 180],
    "format": "netcdf",
}

project_root = Path.cwd()
if project_root.name == "notebooks":
    project_root = project_root.parent

raw_root = project_root / "data" / "raw" / "era5"

# %% [markdown]
# ## Download Loop
#
# Iterates through years, months, and variables to download ERA5 data. Implements retry logic with exponential backoff for robustness.
#
# Requests are submitted with a small pool of concurrent workers rather than one at a time. This is not a way around any limit: the CDS documentation states that the server itself queues any requests beyond what it can currently serve, rather than rejecting them, so submitting a modest number concurrently just lets the server's own scheduler decide the pace. `derived-era5-single-levels-daily-statistics` is a disk-hosted, pre-aggregated CDS product (not a MARS tape archive), so the "one tape at a time" sequential-access guidance for raw ERA5 does not apply here.
#
# We keep the worker count deliberately conservative (5) and each request stays exactly as small as before (one variable, one month, one year) — no batching tricks to dodge per-request limits, just running a few of the existing small requests side by side.

# %%
import random
import threading
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

MAX_WORKERS = 5  # conservative: a handful of the same small per-variable-month requests, run side by side
MAX_RETRIES = 5
INITIAL_BACKOFF = 60  # seconds

raw_root.mkdir(parents=True, exist_ok=True)

# One cdsapi.Client per worker thread; sharing a single client across threads
# is not supported and causes connection issues.
_thread_local = threading.local()


def get_client() -> cdsapi.Client:
    if not hasattr(_thread_local, "client"):
        _thread_local.client = cdsapi.Client()
    return _thread_local.client


print_lock = threading.Lock()


def log(msg: str) -> None:
    with print_lock:
        print(msg)


def download_one(year: int, month: int, variable: str) -> None:
    month_str = f"{month:02d}"
    var_name = variable.replace("_", "").replace("component", "comp").replace("of", "")
    year_dir = raw_root / f"{year}"
    year_dir.mkdir(parents=True, exist_ok=True)
    target_path = year_dir / f"era5_{year}_{month_str}_{var_name}.nc"

    if target_path.exists():
        log(f"Skipping existing file: {target_path.name}")
        return

    request = base_request.copy()
    request["year"] = str(year)
    request["month"] = [month_str]
    request["variable"] = [variable]

    client = get_client()

    for attempt in range(MAX_RETRIES):
        try:
            log(f"Requesting ERA5 data for {variable} {year}-{month_str} (attempt {attempt + 1}/{MAX_RETRIES})")
            client.retrieve(dataset, request, target=str(target_path))
            log(f"Successfully downloaded {target_path.name}")
            return
        except Exception as e:
            log(f"Download failed for {target_path.name} on attempt {attempt + 1}: {e}")
            if attempt < MAX_RETRIES - 1:
                backoff_time = INITIAL_BACKOFF * (2 ** attempt)
                log(f"Retrying {target_path.name} in {backoff_time} seconds...")
                time.sleep(backoff_time)
            else:
                log(f"Failed to download {target_path.name} after {MAX_RETRIES} attempts. Skipping file.")


jobs = [
    (year, month, variable)
    for year in years
    for month in months
    for variable in variables
]

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as pool:
    futures = []
    for year, month, variable in jobs:
        # Small, randomised stagger between submissions so the pool ramps up
        # gradually rather than firing every job at once.
        time.sleep(random.uniform(0.1, 0.5))
        futures.append(pool.submit(download_one, year, month, variable))

    for future in as_completed(futures):
        future.result()  # re-raise any unexpected exception from a worker

print("Download loop complete.")
