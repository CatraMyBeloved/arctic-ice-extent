# %%
import os

import pandas as pd
import geopandas as gpd
import regionmask
import xarray as xr
import dask
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from src.data_utils import *

# %% [markdown]
# # ERA5 Data Transformation and Regional Aggregation
#
# This notebook processes raw ERA5 NetCDF files by:
# 1. Combining monthly variable files into unified datasets
# 2. Applying unit transformations (K→°C, Pa→hPa)
# 3. Computing derived variables (wind speed)
# 4. Aggregating to Arctic regions using spatial masks

# %% [markdown]
# ## Load Sample Data
#
# Load a single month of ERA5 data to explore the structure and variables.

# %%
msl = xr.open_dataset("../data/raw/era5/1979/era5_1979_01_meansealevelpressure.nc", engine="netcdf4")
uwind = xr.open_dataset("../data/raw/era5/1979/era5_1979_01_10mucompwind.nc", engine="netcdf4")
vwind = xr.open_dataset("../data/raw/era5/1979/era5_1979_01_10mvcompwind.nc", engine="netcdf4")
temp = xr.open_dataset("../data/raw/era5/1979/era5_1979_01_2mtemperature.nc")

# %%
def combine_era5_monthly_files():
    """
    Goes through all raw ERA5 files, combines them into one monthly file,
    performs transformations, and saves it to the interim folder.
    
    This function will:
    - Iterate through years 1979 to 2023 and months 1 to 12.
    - Create a destination folder in ../data/interim/era5/ if it doesn't exist.
    - Skip the file creation if the monthly file already exists.
    - Combine mean sea level pressure, u-wind, v-wind, temperature, and precipitation data.
    - Transform units (Kelvin to Celsius, Pa to hPa).
    - Calculate wind speed.
    - Save the processed data as a NetCDF file.
    """
    years = range(1979, 2024)
    months = range(1, 13)

    for year in years:
        output_folder = f"../data/interim/era5/{year}"
        os.makedirs(output_folder, exist_ok=True)

        for month in months:
            month_str = f"{month:02d}"
            output_filepath = f"{output_folder}/{year}_{month_str}.nc"

            if os.path.exists(output_filepath):
                print(f"Skipping {year}-{month_str}: File already exists.")
                continue

            print(f"Processing {year}-{month_str}")

            try:
                msl = xr.open_dataset(f"../data/raw/era5/{year}/era5_{year}_{month_str}_meansealevelpressure.nc",
                                      engine="netcdf4")
                uwind = xr.open_dataset(f"../data/raw/era5/{year}/era5_{year}_{month_str}_10mucompwind.nc",
                                        engine="netcdf4")
                vwind = xr.open_dataset(f"../data/raw/era5/{year}/era5_{year}_{month_str}_10mvcompwind.nc",
                                        engine="netcdf4")
                temp = xr.open_dataset(f"../data/raw/era5/{year}/era5_{year}_{month_str}_2mtemperature.nc",
                                       engine="netcdf4")
                precip = xr.open_dataset(f"../data/raw/era5/{year}/era5_{year}_{month_str}_totalprecipitation.nc",
                                         engine="netcdf4")

                ds = xr.merge([msl, uwind, vwind, temp, precip])
                ds["tp"] = ds["tp"].fillna(0)
                ds["tp"] = ds["tp"].where(ds["tp"] >= 0, 0)

                # Convert temperature from Kelvin to Celsius
                ds["t2m"] = ds["t2m"] - 273.15

                # Convert pressure from Pa to hPa
                ds["msl"] = ds["msl"] / 100.0

                # Calculate wind speed magnitude
                ds["wind_speed"] = np.sqrt(ds["u10"] ** 2 + ds["v10"] ** 2)

                ds.to_netcdf(output_filepath)
            except FileNotFoundError:
                print(f"Could not process {year}-{month_str}: One or more source files not found.")

# %% [markdown]
# ## Combine Monthly Files
#
# Skipping 2001-08: File already exists.
# Skipping 2001-09: File already exists.
# Skipping 2001-10: File already exists.
# Skipping 2001-11: File already exists.
# Skipping 2001-12: File already exists.
# Skipping 2002-01: File already exists.
# Skipping 2002-02: File already exists.
# Skipping 2002-03: File already exists.
# Skipping 2002-04: File already exists.
# Skipping 2002-05: File already exists.
# Skipping 2002-06: File already exists.
# Skipping 2002-07: File already exists.
# Skipping 2002-08: File already exists.
# Skipping 2002-09: File already exists.
# Skipping 2002-10: File already exists.
# Skipping 2002-11: File already exists.
# Skipping 2002-12: File already exists.
# Skipping 2003-01: File already exists.
# Skipping 2003-02: File already exists.
# Skipping 2003-03: File already exists.
# Skipping 2003-04: File already exists.
# Skipping 2003-05: File already exists.
# Skipping 2003-06: File already exists.
# Skipping 2003-07: File already exists.
# Skipping 2003-08: File already exists.
# Skipping 2003-09: File already exists.
# Skipping 2003-10: File already exists.
# Skipping 2003-11: File already exists.
# Skipping 2003-12: File already exists.
# Skipping 2004-01: File already exists.
# Skipping 2004-02: File already exists.
# Skipping 2004-03: File already exists.
# Skipping 2004-04: File already exists.
# Skipping 2004-05: File already exists.
# Skipping 2004-06: File already exists.
# Skipping 2004-07: File already exists.
# Skipping 2004-08: File already exists.
# Skipping 2004-09: File already exists.
# Skipping 2004-10: File already exists.
# Skipping 2004-11: File already exists.
# Skipping 2004-12: File already exists.
# Skipping 2005-01: File already exists.
# Skipping 2005-02: File already exists.
# Skipping 2005-03: File already exists.
# Skipping 2005-04: File already exists.
# Skipping 2005-05: File already exists.
# Skipping 2005-06: File already exists.
# Skipping 2005-07: File already exists.
# Skipping 2005-08: File already exists.
# Skipping 2005-09: File already exists.
# Skipping 2005-10: File already exists.
# Skipping 2005-11: File already exists.
# Skipping 2005-12: File already exists.
# Skipping 2006-01: File already exists.
# Skipping 2006-02: File already exists.
# Skipping 2006-03: File already exists.
# Skipping 2006-04: File already exists.
# Skipping 2006-05: File already exists.
# Skipping 2006-06: File already exists.
# Skipping 2006-07: File already exists.
# Skipping 2006-08: File already exists.
# Skipping 2006-09: File already exists.
# Skipping 2006-10: File already exists.
# Skipping 2006-11: File already exists.
# Skipping 2006-12: File already exists.
# Skipping 2007-01: File already exists.
# Skipping 2007-02: File already exists.
# Skipping 2007-03: File already exists.
# Skipping 2007-04: File already exists.
# Skipping 2007-05: File already exists.
# Skipping 2007-06: File already exists.
# Skipping 2007-07: File already exists.
# Skipping 2007-08: File already exists.
# Skipping 2007-09: File already exists.
# Skipping 2007-10: File already exists.
# Skipping 2007-11: File already exists.
# Skipping 2007-12: File already exists.
# Skipping 2008-01: File already exists.
# Skipping 2008-02: File already exists.
# Skipping 2008-03: File already exists.
# Skipping 2008-04: File already exists.
# Skipping 2008-05: File already exists.
# Skipping 2008-06: File already exists.
# Skipping 2008-07: File already exists.
# Skipping 2008-08: File already exists.
# Skipping 2008-09: File already exists.
# Skipping 2008-10: File already exists.
# Skipping 2008-11: File already exists.
# Skipping 2008-12: File already exists.
# Skipping 2009-01: File already exists.
# Skipping 2009-02: File already exists.
# Skipping 2009-03: File already exists.
# Skipping 2016-11: File already exists.
# Skipping 2016-12: File already exists.
# Skipping 2017-01: File already exists.
# Skipping 2017-02: File already exists.
# Skipping 2017-03: File already exists.
# Skipping 2017-04: File already exists.
# Skipping 2017-05: File already exists.
# Skipping 2017-06: File already exists.
# Skipping 2017-07: File already exists.
# Skipping 2017-08: File already exists.
# Skipping 2017-09: File already exists.
# Skipping 2017-10: File already exists.
# Skipping 2017-11: File already exists.
# Skipping 2017-12: File already exists.
# Skipping 2018-01: File already exists.
# Skipping 2018-02: File already exists.
# Skipping 2018-03: File already exists.
# Skipping 2018-04: File already exists.
# Skipping 2018-05: File already exists.
# Skipping 2018-06: File already exists.
# Skipping 2018-07: File already exists.
# Skipping 2018-08: File already exists.
# Skipping 2018-09: File already exists.
# Skipping 2018-10: File already exists.
# Skipping 2018-11: File already exists.
# Skipping 2018-12: File already exists.
# Skipping 2019-01: File already exists.
# Skipping 2019-02: File already exists.
# Skipping 2019-03: File already exists.
# Skipping 2019-04: File already exists.
# Skipping 2019-05: File already exists.
# Skipping 2019-06: File already exists.
# Skipping 2019-07: File already exists.
# Skipping 2019-08: File already exists.
# Skipping 2019-09: File already exists.
# Skipping 2019-10: File already exists.
# Skipping 2019-11: File already exists.
# Skipping 2019-12: File already exists.
# Skipping 2020-01: File already exists.
# Skipping 2020-02: File already exists.
# Skipping 2020-03: File already exists.
# Skipping 2020-04: File already exists.
# Skipping 2020-05: File already exists.
# Skipping 2020-06: File already exists.
# Skipping 2020-07: File already exists.
# Skipping 2020-08: File already exists.
# Skipping 2020-09: File already exists.
# Skipping 2020-10: File already exists.
# Skipping 2020-11: File already exists.
# Skipping 2020-12: File already exists.
# Skipping 2021-01: File already exists.
# Skipping 2021-02: File already exists.
# Skipping 2021-03: File already exists.
# Skipping 2021-04: File already exists.
# Skipping 2021-05: File already exists.
# Skipping 2021-06: File already exists.
# Skipping 2021-07: File already exists.
# Skipping 2021-08: File already exists.
# Skipping 2021-09: File already exists.
# Skipping 2021-10: File already exists.
# Skipping 2021-11: File already exists.
# Skipping 2021-12: File already exists.
# Skipping 2022-01: File already exists.
# Skipping 2022-02: File already exists.
# Skipping 2022-03: File already exists.
# Skipping 2022-04: File already exists.
# Skipping 2022-05: File already exists.
# Skipping 2022-06: File already exists.
# Skipping 2022-07: File already exists.
# Skipping 2022-08: File already exists.
# Skipping 2022-09: File already exists.
# Skipping 2022-10: File already exists.
# Skipping 2022-11: File already exists.
# Skipping 2022-12: File already exists.
# Skipping 2023-01: File already exists.
# Skipping 2023-02: File already exists.
# Skipping 2023-03: File already exists.
# Skipping 2023-04: File already exists.
# Skipping 2023-05: File already exists.
# Skipping 2023-06: File already exists.
# Skipping 2023-07: File already exists.
# Skipping 2023-08: File already exists.
# Skipping 2023-09: File already exists.
# Skipping 2023-10: File already exists.
# Skipping 2023-11: File already exists.
# Skipping 2023-12: File already exists.

# %% [markdown]
# ## Define Arctic Regions
#
# List NSIDC-defined Arctic regions for spatial aggregation. Pan-Arctic represents the combined Arctic domain.

# %%
regions = [
    'Central_Arctic',
    'Beaufort',
    'Chukchi-NA',
    'Chukchi-Asia',
    'E_Siberian',
    'Laptev',
    'Kara',
    'Barents',
    'E_Greenland',
    'Baffin',
    'St_Lawr',
    'Hudson',
    'Can_Arch',
    'Bering-NA',
    'Bering-Asia',
    'Okhotsk',
    'Bohai',
    'Baltic'
]

# Add pan_arctic as a special region for full Arctic aggregation
all_regions = regions + ['pan_arctic']

# %% [markdown]
# ## Regional Aggregation
#
# Create spatial masks for each region and compute daily statistics (mean, std, p15, p85) for all variables. Output saved as long-format Parquet files.

# %%
def aggregate_to_region_parquets():
    """
    Aggregates ERA5 data by Arctic regions and saves to Parquet files.

    This function:
    - Creates spatial masks for each Arctic region
    - Creates a combined pan-arctic mask from all Arctic regions
    - Processes ERA5 NetCDF files by year/month
    - Computes regional statistics (mean, std, percentiles) for each variable
    - Saves aggregated data in Parquet format with schema: date, region, variable, stat, value
    """
    years = range(1979, 2024)
    months = range(1, 13)
    variables = ['t2m', 'msl', 'u10', 'v10', 'tp', 'wind_speed']
    stats = ['mean', 'std', 'p15', 'p85']

    # Define Arctic regions for pan-arctic aggregation (exclude non-Arctic seas)
    arctic_regions_for_pan_arctic = [
        'Central_Arctic', 'Beaufort', 'Chukchi-NA', 'Chukchi-Asia', 'E_Siberian',
        'Laptev', 'Kara', 'Barents', 'E_Greenland', 'Baffin', 'St_Lawr',
        'Hudson', 'Can_Arch', 'Bering-NA', 'Bering-Asia', 'Okhotsk'
    ]

    shapefiles = get_region_shapefiles()

    sample_ds = xr.open_dataset('../data/interim/era5/1979/1979_01.nc')
    region_masks = {}

    print("Creating region masks...")
    for region in regions:
        region_shape = shapefiles[shapefiles['Region'] == region]['geometry']
        if region_shape.empty:
            print(f"Warning: No geometry found for region {region}")
            continue

        mask = regionmask.mask_geopandas(
            region_shape,
            sample_ds.longitude,
            sample_ds.latitude
        )
        region_masks[region] = mask

        valid_points = (~mask.isnull()).sum()
        print(f"  {region}: {valid_points} valid grid points")

    # Create combined pan-arctic mask from all Arctic regions
    print("Creating pan-arctic combined mask...")
    pan_arctic_shapes = shapefiles[shapefiles['Region'].isin(arctic_regions_for_pan_arctic)]['geometry']

    if not pan_arctic_shapes.empty:
        pan_arctic_mask = regionmask.mask_geopandas(
            pan_arctic_shapes,
            sample_ds.longitude,
            sample_ds.latitude,
            overlap=False
        )
        region_masks['pan_arctic'] = pan_arctic_mask

        valid_points = (~pan_arctic_mask.isnull()).sum()
        print(f"  pan_arctic: {valid_points} valid grid points (combined from {len(arctic_regions_for_pan_arctic)} Arctic regions)")
    else:
        print("  Warning: Could not create pan-arctic mask")

    sample_ds.close()

    output_dir = "../data/processed/parquet"
    os.makedirs(output_dir, exist_ok=True)

    # Process all regions including pan_arctic
    all_processing_regions = regions + ['pan_arctic']

    for year in years:
        print(f"Processing year {year}...")
        yearly_data = []

        for month in months:
            month_str = f"{month:02d}"
            nc_filepath = f"../data/interim/era5/{year}/{year}_{month_str}.nc"

            if not os.path.exists(nc_filepath):
                print(f"  Skipping {year}-{month_str}: File not found")
                continue

            print(f"  Processing {year}-{month_str}")

            try:
                ds = xr.open_dataset(nc_filepath)

                for time_idx in range(len(ds.valid_time)):
                    date = pd.to_datetime(ds.valid_time.values[time_idx]).date()
                    daily_data = ds.isel(valid_time=time_idx)

                    # Process all regions (regional + pan_arctic)
                    for region in all_processing_regions:
                        if region not in region_masks:
                            continue

                        mask = region_masks[region]

                        for var in variables:
                            if var not in daily_data.data_vars:
                                continue

                            masked_data = daily_data[var].where(~mask.isnull())

                            if masked_data.isnull().all():
                                continue

                            for stat in stats:
                                if stat == 'mean':
                                    value = float(masked_data.mean().values)
                                elif stat == 'std':
                                    value = float(masked_data.std().values)
                                elif stat == 'p15':
                                    value = float(masked_data.quantile(0.15).values)
                                elif stat == 'p85':
                                    value = float(masked_data.quantile(0.85).values)

                                if pd.isna(value):
                                    continue

                                yearly_data.append({
                                    'date': date,
                                    'region': region,
                                    'variable': var,
                                    'stat': stat,
                                    'value': value
                                })

                ds.close()

            except Exception as e:
                print(f"  Error processing {year}-{month_str}: {e}")
                continue

        if yearly_data:
            df = pd.DataFrame(yearly_data)
            parquet_filepath = f"{output_dir}/era5_regional_{year}.parquet"
            df.to_parquet(parquet_filepath, index=False)
            print(f"  Saved {len(df)} records to {parquet_filepath}")
        else:
            print(f"  No data to save for year {year}")



def get_region_shapefiles():
    shapefile = gpd.read_file("../data/raw/shapefiles_regions/NSIDC-0780_SeaIceRegions_NH_v1.0.shp")
    return shapefile

# %%
aggregate_to_region_parquets()
# Out:
# Creating region masks...
#   Central_Arctic: <xarray.DataArray 'mask' ()> Size: 8B
# array(63300)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   Beaufort: <xarray.DataArray 'mask' ()> Size: 8B
# array(4661)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   Chukchi-NA: <xarray.DataArray 'mask' ()> Size: 8B
# array(3800)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   Chukchi-Asia: <xarray.DataArray 'mask' ()> Size: 8B
# array(190)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   E_Siberian: <xarray.DataArray 'mask' ()> Size: 8B
# array(5802)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   Laptev: <xarray.DataArray 'mask' ()> Size: 8B
# array(6922)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   Kara: <xarray.DataArray 'mask' ()> Size: 8B
# array(9749)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   Barents: <xarray.DataArray 'mask' ()> Size: 8B
# array(11424)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   E_Greenland: <xarray.DataArray 'mask' ()> Size: 8B
# array(16020)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   Baffin: <xarray.DataArray 'mask' ()> Size: 8B
# array(11531)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   St_Lawr: <xarray.DataArray 'mask' ()> Size: 8B
# array(0)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   Hudson: <xarray.DataArray 'mask' ()> Size: 8B
# array(6656)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   Can_Arch: <xarray.DataArray 'mask' ()> Size: 8B
# array(9609)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   Bering-NA: <xarray.DataArray 'mask' ()> Size: 8B
# array(3871)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   Bering-Asia: <xarray.DataArray 'mask' ()> Size: 8B
# array(2596)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   Okhotsk: <xarray.DataArray 'mask' ()> Size: 8B
# array(3192)
# Coordinates:
#     number   int64 8B 0 valid grid points
# C:\Users\stein\AppData\Local\Temp\ipykernel_30760\3166108365.py:36: UserWarning: No gridpoint belongs to any region. Returning an all-NaN mask.
#   mask = regionmask.mask_geopandas(
# C:\Users\stein\AppData\Local\Temp\ipykernel_30760\3166108365.py:36: UserWarning: No gridpoint belongs to any region. Returning an all-NaN mask.
#   mask = regionmask.mask_geopandas(
#   Bohai: <xarray.DataArray 'mask' ()> Size: 8B
# array(0)
# Coordinates:
#     number   int64 8B 0 valid grid points
#   Baltic: <xarray.DataArray 'mask' ()> Size: 8B
# array(3169)
# Coordinates:
#     number   int64 8B 0 valid grid points
# Creating pan-arctic combined mask...
#   pan_arctic: <xarray.DataArray 'mask' ()> Size: 8B
# array(159300)
# Coordinates:
#     number   int64 8B 0 valid grid points (combined from 16 Arctic regions)
# Processing year 1979...
#   Processing 1979-01
#   Processing 1979-02
#   Processing 1979-03
#   Processing 1979-04
#   Processing 1979-05
#   Processing 1979-06
#   Processing 1979-07
#   Processing 1979-08
#   Processing 1979-09
#   Processing 1979-10
#   Processing 1979-11
#   Processing 1979-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_1979.parquet
# Processing year 1980...
#   Processing 1980-01
#   Processing 1980-02
#   Processing 1980-03
#   Processing 1980-04
#   Processing 1980-05
#   Processing 1980-06
#   Processing 1980-07
#   Processing 1980-08
#   Processing 1980-09
#   Processing 1980-10
#   Processing 1980-11
#   Processing 1980-12
#   Saved 149328 records to ../data/processed/parquet/era5_regional_1980.parquet
# Processing year 1981...
#   Processing 1981-01
#   Processing 1981-02
#   Processing 1981-03
#   Processing 1981-04
#   Processing 1981-05
#   Processing 1981-06
#   Processing 1981-07
#   Processing 1981-08
#   Processing 1981-09
#   Processing 1981-10
#   Processing 1981-11
#   Processing 1981-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_1981.parquet
# Processing year 1982...
#   Processing 1982-01
#   Processing 1982-02
#   Processing 1982-03
#   Processing 1982-04
#   Processing 1982-05
#   Processing 1982-06
#   Processing 1982-07
#   Processing 1982-08
#   Processing 1982-09
#   Processing 1982-10
#   Processing 1982-11
#   Processing 1982-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_1982.parquet
# Processing year 1983...
#   Processing 1983-01
#   Processing 1983-02
#   Processing 1983-03
#   Processing 1983-04
#   Processing 1983-05
#   Processing 1983-06
#   Processing 1983-07
#   Processing 1983-08
#   Processing 1983-09
#   Processing 1983-10
#   Processing 1983-11
#   Processing 1983-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_1983.parquet
# Processing year 1984...
#   Processing 1984-01
#   Processing 1984-02
#   Processing 1984-03
#   Processing 1984-04
#   Processing 1984-05
#   Processing 1984-06
#   Processing 1984-07
#   Processing 1984-08
#   Processing 1984-09
#   Processing 1984-10
#   Processing 1984-11
#   Processing 1984-12
#   Saved 149328 records to ../data/processed/parquet/era5_regional_1984.parquet
# Processing year 1985...
#   Processing 1985-01
#   Processing 1985-02
#   Processing 1985-03
#   Processing 1985-04
#   Processing 1985-05
#   Processing 1985-06
#   Processing 1985-07
#   Processing 1985-08
#   Processing 1985-09
#   Processing 1985-10
#   Processing 1985-11
#   Processing 1985-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_1985.parquet
# Processing year 1986...
#   Processing 1986-01
#   Processing 1986-02
#   Processing 1986-03
#   Processing 1986-04
#   Processing 1986-05
#   Processing 1986-06
#   Processing 1986-07
#   Processing 1986-08
#   Processing 1986-09
#   Processing 1986-10
#   Processing 1986-11
#   Processing 1986-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_1986.parquet
# Processing year 1987...
#   Processing 1987-01
#   Processing 1987-02
#   Processing 1987-03
#   Processing 1987-04
#   Processing 1987-05
#   Processing 1987-06
#   Processing 1987-07
#   Processing 1987-08
#   Processing 1987-09
#   Processing 1987-10
#   Processing 1987-11
#   Processing 1987-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_
12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_1997.parquet
# Processing year 1998...
#   Processing 1998-01
#   Processing 1998-02
#   Processing 1998-03
#   Processing 1998-04
#   Processing 1998-05
#   Processing 1998-06
#   Processing 1998-07
#   Processing 1998-08
#   Processing 1998-09
#   Processing 1998-10
#   Processing 1998-11
#   Processing 1998-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_1998.parquet
# Processing year 1999...
#   Processing 1999-01
#   Processing 1999-02
#   Processing 1999-03
#   Processing 1999-04
#   Processing 1999-05
#   Processing 1999-06
#   Processing 1999-07
#   Processing 1999-08
#   Processing 1999-09
#   Processing 1999-10
#   Processing 1999-11
#   Processing 1999-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_1999.parquet
# Processing year 2000...
#   Processing 2000-01
#   Processing 2000-02
#   Processing 2000-03
#   Processing 2000-04
#   Processing 2000-05
#   Processing 2000-06
#   Processing 2000-07
#   Processing 2000-08
#   Processing 2000-09
#   Processing 2000-10
#   Processing 2000-11
#   Processing 2000-12
#   Saved 149328 records to ../data/processed/parquet/era5_regional_2000.parquet
# Processing year 2001...
#   Processing 2001-01
#   Processing 2001-02
#   Processing 2001-03
#   Processing 2001-04
#   Processing 2001-05
#   Processing 2001-06
#   Processing 2001-07
#   Processing 2001-08
#   Processing 2001-09
#   Processing 2001-10
#   Processing 2001-11
#   Processing 2001-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2001.parquet
# Processing year 2002...
#   Processing 2002-01
#   Processing 2002-02
#   Processing 2002-03
#   Processing 2002-04
#   Processing 2002-05
#   Processing 2002-06
#   Processing 2002-07
#   Processing 2002-08
#   Processing 2002-09
#   Processing 2002-10
#   Processing 2002-11
#   Processing 2002-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2002.parquet
# Processing year 2003...
#   Processing 2003-01
#   Processing 2003-02
#   Processing 2003-03
#   Processing 2003-04
#   Processing 2003-05
#   Processing 2003-06
#   Processing 2003-07
#   Processing 2003-08
#   Processing 2003-09
#   Processing 2003-10
#   Processing 2003-11
#   Processing 2003-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2003.parquet
# Processing year 2004...
#   Processing 2004-01
#   Processing 2004-02
#   Processing 2004-03
#   Processing 2004-04
#   Processing 2004-05
#   Processing 2004-06
#   Processing 2004-07
#   Processing 2004-08
#   Processing 2004-09
#   Processing 2004-10
#   Processing 2004-11
#   Processing 2004-12
#   Saved 149328 records to ../data/processed/parquet/era5_regional_2004.parquet
# Processing year 2005...
#   Processing 2005-01
#   Processing 2005-02
#   Processing 2005-03
#   Processing 2005-04
#   Processing 2005-05
#   Processing 2005-06
#   Processing 2005-07
#   Processing 2005-08
#   Processing 2005-09
#   Processing 2005-10
#   Processing 2005-11
#   Processing 2005-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2005.parquet
# Processing year 2006...
#   Processing 2006-01
#   Processing 2006-02
#   Processing 2006-03
#   Processing 2006-04
#   Processing 2006-05
#   Processing 2006-06
#   Processing 2006-07
#   Processing 2006-08
#   Processing 2006-09
#   Processing 2006-10
#   Processing 2006-11
#   Processing 2006-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2006.parquet
# Processing year 2007...
#   Processing 2007-01
#   Processing 2007-02
#   Processing 2007-03
#   Processing 2007-04
#   Processing 2007-05
#   Processing 2007-06
#   Processing 2007-07
#   Processing 2007-08
#   Processing 2007-09
#   Processing 2007-10
#   Processing 2007-11
#   Processing 2007-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2007.parquet
# Processing year 2008...
#   Processing 2008-01
#   Processing 2008-02
#   Processing 2008-03
#   Processing 2008-04
#   Processing 2008-05
#   Processing 2008-06
#   Processing 2008-07
#   Processing 2008-08
#   Processing 2008-09
#   Processing 2008-10
#   Processing 2008-11
#   Processing 2008-12
#   Saved 149328 records to ../data/processed/parquet/era5_regional_2008.parquet
# Processing year 2009...
#   Processing 2009-01
#   Processing 2009-02
#   Processing 2009-03
#   Processing 2009-04
#   Processing 2009-05
#   Processing 2009-06
#   Processing 2009-07
#   Processing 2009-08
#   Processing 2009-09
#   Processing 2009-10
#   Processing 2009-11
#   Processing 2009-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2009.parquet
# Processing year 2010...
#   Processing 2010-01
#   Processing 2010-02
#   Processing 2010-03
#   Processing 2010-04
#   Processing 2010-05
#   Processing 2010-06
#   Processing 2010-07
#   Processing 2010-08
#   Processing 2010-09
#   Processing 2010-10
#   Processing 2010-11
#   Processing 2010-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2010.parquet
# Processing year 2011...
#   Processing 2011-01
#   Processing 2011-02
#   Processing 2011-03
#   Processing 2011-04
#   Processing 2011-05
#   Processing 2011-06
#   Processing 2011-07
#   Processing 2011-08
#   Processing 2011-09
#   Processing 2011-10
#   Processing 2011-11
#   Processing 2011-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2011.parquet
# Processing year 2012...
#   Processing 2012-01
#   Processing 2012-02
#   Processing 2012-03
#   Processing 2012-04
#   Processing 2012-05
#   Processing 2012-06
#   Processing 2012-07
#   Processing 2012-08
#   Processing 2012-09
#   Processing 2012-10
#   Processing 2012-11
#   Processing 2012-12
#   Saved 149328 records to ../data/processed/parquet/era5_regional_2012.parquet
# Processing year 2013...
#   Processing 2013-01
#   Processing 2013-02
#   Processing 2013-03
#   Processing 2013-04
#   Processing 2013-05
#   Processing 2013-06
#   Processing 2013-07
#   Processing 2013-08
#   Processing 2013-09
#   Processing 2013-10
#   Processing 2013-11
#   Processing 2013-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2013.parquet
# Processing year 2014...
#   Processing 2014-01
#   Processing 2014-02
#   Processing 2014-03
#   Processing 2014-04
#   Processing 2014-05
#   Processing 2014-06
#   Processing 2014-07
#   Processing 2014-08
#   Processing 2014-09
#   Processing 2014-10
#   Processing 2014-11
#   Processing 2014-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2014.parquet
# Processing year 2015...
#   Processing 2015-01
#   Processing 2015-02
#   Processing 2015-03
#   Processing 2015-04
#   Processing 2015-05
#   Processing 2015-06
#   Processing 2015-07
#   Processing 2015-08
#   Processing 2015-09
#   Processing 2015-10
#   Processing 2015-11
#   Processing 2015-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2015.parquet
# Processing year 2016...
#   Processing 2016-01
#   Processing 2016-02
#   Processing 2016-03
#   Processing 2016-04
#   Processing 2016-05
#   Processing 2016-06
#   Processing 2016-07
#   Processing 2016-08
#   Processing 2016-09
#   Processing 2016-10
#   Processing 2016-11
#   Processing 2016-12
#   Saved 149328 records to ../data/processed/parquet/era5_regional_2016.parquet
# Processing year 2017...
#   Processing 2017-01
#   Processing 2017-02
#   Processing 2017-03
#   Processing 2017-04
#   Processing 2017-05
#   Processing 2017-06
#   Processing 2017-07
#   Processing 2017-08
#   Processing 2017-09
#   Processing 2017-10
#   Processing 2017-11
#   Processing 2017-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2017.parquet
# Processing year 2018...
#   Processing 2018-01
#   Processing 2018-02
#   Processing 2018-03
#   Processing 2018-04
#   Processing 2018-05
#   Processing 2018-06
#   Processing 2018-07
#   Processing 2018-08
#   Processing 2018-09
#   Processing 2018-10
#   Processing 2018-11
#   Processing 2018-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2018.parquet
# Processing year 2019...
#   Processing 2019-01
#   Processing 2019-02
#   Processing 2019-03
#   Processing 2019-04
#   Processing 2019-05
#   Processing 2019-06
#   Processing 2019-07
#   Processing 2019-08
#   Processing 2019-09
#   Processing 2019-10
#   Processing 2019-11
#   Processing 2019-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2019.parquet
# Processing year 2020...
#   Processing 2020-01
#   Processing 2020-02
#   Processing 2020-03
#   Processing 2020-04
#   Processing 2020-05
#   Processing 2020-06
#   Processing 2020-07
#   Processing 2020-08
#   Processing 2020-09
#   Processing 2020-10
#   Processing 2020-11
#   Processing 2020-12
#   Saved 149328 records to ../data/processed/parquet/era5_regional_2020.parquet
# Processing year 2021...
#   Processing 2021-01
#   Processing 2021-02
#   Processing 2021-03
#   Processing 2021-04
#   Processing 2021-05
#   Processing 2021-06
#   Processing 2021-07
#   Processing 2021-08
#   Processing 2021-09
#   Processing 2021-10
#   Processing 2021-11
#   Processing 2021-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2021.parquet
# Processing year 2022...
#   Processing 2022-01
#   Processing 2022-02
#   Processing 2022-03
#   Processing 2022-04
#   Processing 2022-05
#   Processing 2022-06
#   Processing 2022-07
#   Processing 2022-08
#   Processing 2022-09
#   Processing 2022-10
#   Processing 2022-11
#   Processing 2022-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2022.parquet
# Processing year 2023...
#   Processing 2023-01
#   Processing 2023-02
#   Processing 2023-03
#   Processing 2023-04
#   Processing 2023-05
#   Processing 2023-06
#   Processing 2023-07
#   Processing 2023-08
#   Processing 2023-09
#   Processing 2023-10
#   Processing 2023-11
#   Processing 2023-12
#   Saved 148920 records to ../data/processed/parquet/era5_regional_2023.parquet

# %% [markdown]
# ## Merge with Ice Extent Data
#
# Load regional atmospheric statistics and merge with sea ice extent from database. Handles region name mapping between ERA5 and NSIDC conventions.

# %%
def load_data_for_year(year, region):
    """
    Loads and merges ERA5 atmospheric data with sea ice extent data for a specific year and region.

    Handles the format mismatch between long-format parquet files and wide-format database tables
    by pivoting the atmospheric data and mapping region names between datasets.

    Parameters:
    - year (int): The year for which to load the data
    - region (str): The target region name (using database naming convention)

    Returns:
    - pd.DataFrame: Merged dataset with atmospheric features as columns and ice extent data
    """
    region_mapping = {
        'Central_Arctic': 'Central',
        'Chukchi-NA': 'Chukchi',
        'Chukchi-Asia': 'Chukchi',
        'Bering-NA': 'Bering',
        'Bering-Asia': 'Bering',
        'Can_Arch': 'CanadianArchipelago',
        'E_Greenland': 'Greenland',
        'E_Siberian': 'East',
        'Baffin': 'Baffin',
        'Barents': 'Barents',
        'Beaufort': 'Beaufort',
        'Hudson': 'Hudson',
        'Kara': 'Kara',
        'Laptev': 'Laptev',
        'Okhotsk': 'Okhotsk',
        'pan_arctic': 'pan_arctic'  # Pan-arctic maps to itself
    }

    parquet_filepath = f"../data/processed/parquet/era5_regional_{year}.parquet"

    if not os.path.exists(parquet_filepath):
        raise FileNotFoundError(f"No data found for year {year} at {parquet_filepath}")

    df_atmospheric = pd.read_parquet(parquet_filepath)

    # Handle pan-arctic region - it maps directly
    if region == 'pan_arctic':
        df_filtered = df_atmospheric[df_atmospheric['region'] == 'pan_arctic'].copy()
        df_filtered['mapped_region'] = 'pan_arctic'
    else:
        # Handle regional data with mapping
        df_atmospheric['mapped_region'] = df_atmospheric['region'].map(region_mapping)
        df_filtered = df_atmospheric[df_atmospheric['mapped_region'] == region].copy()

    if df_filtered.empty:
        available_regions = df_atmospheric['region'].unique() if region == 'pan_arctic' else df_atmospheric['mapped_region'].dropna().unique()
        raise ValueError(f"No data found for region '{region}'. Available regions: {sorted(available_regions)}")

    df_filtered['var_stat'] = df_filtered['variable'] + '_' + df_filtered['stat']
    df_wide = df_filtered.pivot_table(
        index=['date', 'mapped_region'],
        columns='var_stat',
        values='value',
        aggfunc='first'
    ).reset_index()

    df_wide = df_wide.rename(columns={'mapped_region': 'region'})
    df_wide.columns.name = None

    df_ice_extent = load_yearly_data_from_database(year, region)
    df_merged = pd.merge(df_wide, df_ice_extent, on=['date', 'region'], how='left')

    return df_merged

# %%
test = load_data_for_year(2000, 'pan_arctic')
# Out:
# Merged dataset shape: (366, 27)
# Columns: ['date', 'region', 'msl_mean', 'msl_p15', 'msl_p85', 'msl_std', 't2m_mean', 't2m_p15', 't2m_p85', 't2m_std', 'tp_mean', 'tp_p15', 'tp_p85', 'tp_std', 'u10_mean', 'u10_p15', 'u10_p85', 'u10_std', 'v10_mean', 'v10_p15', 'v10_p85', 'v10_std', 'wind_speed_mean', 'wind_speed_p15', 'wind_speed_p85', 'wind_speed_std', 'extent']
#
# Sample merged data:
#          date      region     msl_mean     msl_p15      msl_p85    msl_std  \
# 0  2000-01-01  pan_arctic  1008.869080  985.222260  1034.979431  21.064962
# 1  2000-01-02  pan_arctic  1010.056396  989.708649  1034.662048  18.560568
# 2  2000-01-03  pan_arctic  1012.788940  996.131491  1034.177856  17.217007
# 3  2000-01-04  pan_arctic  1014.597534  998.398438  1036.304169  17.397156
# 4  2000-01-05  pan_arctic  1016.404175  999.982178  1038.880463  17.708139
#
#     t2m_mean    t2m_p15   t2m_p85    t2m_std  ...   u10_std  v10_mean  \
# 0 -17.471605 -28.960815 -6.537964  10.528247  ...  5.381142  0.618569
# 1 -17.050108 -29.168958 -6.451599  10.853907  ...  5.684670  0.428814
# 2 -17.903070 -29.678299 -7.385760  10.958343  ...  5.093259  0.253729
# 3 -18.603136 -29.990244 -7.643890  10.554400  ...  4.680056  0.013618
# 4 -19.167580 -30.936798 -6.622345  10.876908  ...  4.553324  0.065259
#
#     v10_p15   v10_p85   v10_std  wind_speed_mean  wind_speed_p15  \
# 0 -4.527481  6.642685  5.088878         6.870444        2.927431
# 1 -5.540627  6.047057  5.083048         6.943417        2.756709
# 2 -5.908349  6.629603  5.555640         6.856953        2.835737
# 3 -5.902374  7.121136  6.097432         6.735631        2.311046
# 4 -5.787661  7.733897  6.006589         6.559560        2.300659
#
#    wind_speed_p85  wind_speed_std  extent
# 0       10.253579        3.433978  13.442
# 1       10.310209        3.400950  13.539
# 2       10.033603        3.312859  13.630
# 3       10.945424        3.846028  13.657
# 4       10.729930        3.801072  13.678
#
# [5 rows x 27 columns]
#
# Data availability:
# - Atmospheric records: 366
# - Ice extent records: 366
# - Complete records: 366
